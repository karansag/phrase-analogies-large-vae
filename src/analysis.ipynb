# %%
# !pip install funcy
# %env OPTIMUS_CHECKPOINT_DIR=../pretrained_models/optimus_snli10/checkpoint-31250/

# %%
"""
Import our dependencies
"""
import pandas as pd
import numpy as np
import buckets as b

# %%
plurals_filename = b.get_file("s3://scored/plurals_data_scored.csv")
opposites_filename = b.get_file("s3://scored/opposite_data_scored.csv")
comparatives_filename = b.get_file("s3://scored/comparative_data_scored.csv")
plurals = pd.read_csv(plurals_filename)
opposites = pd.read_csv(opposites_filename)
comparatives = pd.read_csv(comparatives_filename)
# Out:
# Downloading file from scored/plurals_data_scored.csv to /tmp/plurals_data_scored.csv
# Downloading file from scored/opposite_data_scored.csv to /tmp/opposite_data_scored.csv
# Downloading file from scored/comparative_data_scored.csv to /tmp/comparative_data_scored.csv

# %% [markdown]
# ## Plurals

# %%
print("Counts of each type of value within the plurals dataset")
plural_type_counts = plurals.subcategory.value_counts()
plural_type_counts
# Out:
# Counts of each type of value within the plurals dataset
# plural|from-single                  5007
# plural|to-some|indefinite            418
# plural|to-many|indefinite            410
# plural|to-twenty two|indefinite      408
# plural|to-ten|indefinite             408
# plural|to-various|indefinite         379
# plural|to-one hundred|indefinite     370
# plural|to-five|indefinite            362
# plural|to-twenty|indefinite          357
# plural|to-three|indefinite           335
# plural|to-six|indefinite             333
# plural|to-two|indefinite             318
# plural|to-two hundred|indefinite     300
# plural|to-nine|indefinite            298
# plural|to-four|indefinite            292
# plural|to-two hundred|definite         2
# plural|to-twenty|definite              2
# plural|to-six|definite                 1
# Name: subcategory, dtype: int64

# %%
print("Percentage of each type which were found to be exact matches")
(plurals.groupby(by="subcategory")['score_0_exact'].agg("sum") / plural_type_counts) * 100
# Out:
# Percentage of each type which were found to be exact matches
# plural|from-single                   8.168564
# plural|to-five|indefinite            4.972376
# plural|to-four|indefinite           11.986301
# plural|to-many|indefinite            3.658537
# plural|to-nine|indefinite            0.671141
# plural|to-one hundred|indefinite     0.000000
# plural|to-six|definite               0.000000
# plural|to-six|indefinite             2.702703
# plural|to-some|indefinite            6.220096
# plural|to-ten|indefinite             1.470588
# plural|to-three|indefinite          11.641791
# plural|to-twenty two|indefinite      0.000000
# plural|to-twenty|definite            0.000000
# plural|to-twenty|indefinite          0.560224
# plural|to-two hundred|definite       0.000000
# plural|to-two hundred|indefinite     0.000000
# plural|to-two|indefinite             9.748428
# plural|to-various|indefinite        10.554090
# dtype: float64

# %%
print("Evaluating means of bleu scores")
plurals.groupby(by="subcategory")['score_0_bleu'].agg("mean").round(4)
# Out:
# Evaluating means of bleu scores
# subcategory
# plural|from-single                  0.3253
# plural|to-five|indefinite           0.2728
# plural|to-four|indefinite           0.3607
# plural|to-many|indefinite           0.2854
# plural|to-nine|indefinite           0.2302
# plural|to-one hundred|indefinite    0.1659
# plural|to-six|definite              0.0000
# plural|to-six|indefinite            0.2679
# plural|to-some|indefinite           0.2857
# plural|to-ten|indefinite            0.2479
# plural|to-three|indefinite          0.3405
# plural|to-twenty two|indefinite     0.1785
# plural|to-twenty|definite           0.3078
# plural|to-twenty|indefinite         0.2299
# plural|to-two hundred|definite      0.0626
# plural|to-two hundred|indefinite    0.2163
# plural|to-two|indefinite            0.3685
# plural|to-various|indefinite        0.3402
# Name: score_0_bleu, dtype: float64

# %%
print("Median bleu score of each subcategory")
plurals.groupby(by="subcategory")['score_0_bleu'].agg("median").round(6)
# Out:
# Median bleu score of each subcategory
# subcategory
# plural|from-single                  0.269111
# plural|to-five|indefinite           0.166029
# plural|to-four|indefinite           0.304200
# plural|to-many|indefinite           0.182124
# plural|to-nine|indefinite           0.000292
# plural|to-one hundred|indefinite    0.000159
# plural|to-six|definite              0.000000
# plural|to-six|indefinite            0.182071
# plural|to-some|indefinite           0.203245
# plural|to-ten|indefinite            0.000336
# plural|to-three|indefinite          0.270657
# plural|to-twenty two|indefinite     0.000184
# plural|to-twenty|definite           0.307814
# plural|to-twenty|indefinite         0.111170
# plural|to-two hundred|definite      0.062622
# plural|to-two hundred|indefinite    0.000300
# plural|to-two|indefinite            0.324668
# plural|to-various|indefinite        0.263050
# Name: score_0_bleu, dtype: float64

# %%
print("Percent of exact values from entire plural set")
(plurals['score_0_exact'].agg("sum") / len(plurals.index)) * 100
# Out:
# Percent of exact values from entire plural set
# 6.32

# %%
print("Average bleu score for plurals")
plurals['score_0_bleu'].agg("mean").round(4)
# Out:
# Average bleu score for plurals
# 0.297

# %%
print("Median bleu score for plurals")
plurals['score_0_bleu'].agg("median").round(6)
# Out:
# Median bleu score for plurals
# 0.224204

# %%
print("Percent of exact values from plurals where subcategory is not to-single")
(plurals[plurals['subcategory'] != 'plural|from-single']['score_0_exact'].agg("sum") / len(plurals[plurals['subcategory'] != 'plural|from-single'].index)) * 100
# Out:
# Percent of exact values from plurals where subcategory is not to-single
# 4.4662527538553976

# %%
print("Average bleu score for plurals where subcategory is not single")
plurals[plurals['subcategory'] != 'plural|from-single']['score_0_bleu'].agg("mean").round(4)
# Out:
# Average bleu score for plurals where subcategory is not single
# 0.2687

# %%
print("Median bleu score for plurals where subcategory is not single")
plurals[plurals['subcategory'] != 'plural|from-single']['score_0_bleu'].agg("median").round(6)
# Out:
# Median bleu score for plurals where subcategory is not single
# 0.161886

# %%
print("Examples of exact matches where not \"to-single\"")
plurals.query('score_0_exact == 1 & subcategory != \'plural|from-single\'').sample(n=20)
# Out:
# Examples of exact matches where not "to-single"
#       Unnamed: 0                                                  a  \
# 1982        1982  A man on a street in a bright t-shirt holds so...
# 1652        1652  A man is sitting with his head facing down, wh...
# 7787        7787  A woman in a blue shirt is sitting at a table ...
# 6500        6500            A dog jumps to catch a toy in the snow.
# 57            57                  A man wakeboards on choppy water.
# 8921        8921  A man is sitting with his head facing down, wh...
# 9445        9445  A man with a gray shirt holds a young infant i...
# 4798        4798           A man dances with a fire baton at night.
# 846          846  A child with a brightly colored shirt plays ou...
# 7994        7994                A man in costume is ringing a bell.
# 9499        9499                           A man riding a dirt bike
# 7507        7507  A woman in a green jacket and black sunglasses...
# 8438        8438                    A man sitting in a barber shop.
# 6304        6304  A woman in blue jeans and a dark jacket walks ...
# 3617        3617  A woman in costume is marching with a large drum.
# 8024        8024  A man in a bright green shirt shows a woman in...
# 8302        8302  A man in a green shirt holds out a clipboard f...
# 6898        6898            A man sitting on a scooter on the curb.
# 8876        8876  A woman in a black and orange jacket throws a ...
# 8097        8097  A man with a bright green shirt is talking to ...
#
#                                                       b  \
# 1982  four men on a street in a bright t-shirt holds...
# 1652   men are sitting with his head facing down, wh...
# 7787   women in a blue shirt are sitting at a table ...
# 6500         six dogs jumps to catch a toy in the snow.
# 57                  ten men wakeboards on choppy water.
# 8921   men are sitting with his head facing down, wh...
# 9445  four men with a gray shirt holds a young infan...
# 4798       three men dances with a fire baton at night.
# 846    children with a brightly colored shirt play o...
# 7994             ten men in costume are ringing a bell.
# 9499                        some men riding a dirt bike
# 7507  ten women in a green jacket and black sunglass...
# 8438                  two men sitting in a barber shop.
# 6304  five women in blue jeans and a dark jacket wal...
# 3617   women in costume are marching with a large drum.
# 8024  many men in a bright green shirt shows a woman...
# 8302  some men in a green shirt holds out a clipboar...
# 6898          two men sitting on a scooter on the curb.
# 8876   women in a black and orange jacket throws a s...
# 8097  four men with a bright green shirt are talking...
#
#                                                       c  \
# 1982  A man is on a ladder which is leaning against ...
# 1652                             A dog swims in a pool.
# 7787                              A dog pulling a rope.
# 6500         A man sitting down talking on a cellphone.
# 57                 A woman paddles a boat down a river.
# 8921  A man playing a round of golf at the golf course.
# 9445  A man is holding what appears to be a candle h...
# 4798     A woman is peering into a cooler of ice cream.
# 846         A woman is pushing a young girl in a swing.
# 7994   A man in blue shorts rides a bike down a street.
# 9499          a man in a gray shirt next to a white van
# 7507          A man in a hat is reaching toward a sign.
# 8438    A man wearing a leather coat and a white shirt.
# 6304        A man in green pants walking down the road.
# 3617  A man is resting atop concrete structure in a ...
# 8024  A man wearing safety goggles is repairing a bi...
# 8302                 A man looking into a train engine.
# 6898                     A dog is running on a pathway.
# 8876                       A man doing a bicycle trick.
# 8097  A woman sitting against a brick wall inside a ...
#
#                                                       d       category  \
# 1982  four men are on a ladder which is leaning agai...        neutral
# 1652                               dogs swim in a pool.  contradiction
# 7787                               dogs pulling a rope.        neutral
# 6500       six men sitting down talking on a cellphone.        neutral
# 57               ten women paddles a boat down a river.  contradiction
# 8921    men playing a round of golf at the golf course.  contradiction
# 9445  four men are holding what appears to be a cand...        neutral
# 4798  three women are peering into a cooler of ice c...        neutral
# 846          women are pushing a young girl in a swing.        neutral
# 7994  ten men in blue shorts ride a bike down a street.        neutral
# 9499       some men in a gray shirt next to a white van        neutral
# 7507       ten men in a hat are reaching toward a sign.     entailment
# 8438  two men wearing a leather coat and a white shirt.  contradiction
# 6304     five men in green pants walking down the road.  contradiction
# 3617   men are resting atop concrete structure in a ...     entailment
# 8024  many men wearing safety goggles are repairing ...        neutral
# 8302               two men looking into a train engine.        neutral
# 6898                 two dogs are running on a pathway.  contradiction
# 8876                         men doing a bicycle trick.        neutral
# 8097  four women sitting against a brick wall inside...        neutral
#
#                        subcategory  \
# 1982     plural|to-four|indefinite
# 1652  plural|to-various|indefinite
# 7787  plural|to-various|indefinite
# 6500      plural|to-six|indefinite
# 57        plural|to-ten|indefinite
# 8921  plural|to-various|indefinite
# 9445     plural|to-four|indefinite
# 4798    plural|to-three|indefinite
# 846   plural|to-various|indefinite
# 7994      plural|to-ten|indefinite
# 9499     plural|to-some|indefinite
# 7507      plural|to-ten|indefinite
# 8438      plural|to-two|indefinite
# 6304     plural|to-five|indefinite
# 3617  plural|to-various|indefinite
# 8024     plural|to-many|indefinite
# 8302      plural|to-two|indefinite
# 6898      plural|to-two|indefinite
# 8876  plural|to-various|indefinite
# 8097     plural|to-four|indefinite
#
#                                                  pred_0  score_0_bleu  \
# 1982  four men are on a ladder which is leaning agai...           1.0
# 1652                               dogs swim in a pool.           1.0
# 7787                               dogs pulling a rope.           1.0
# 6500       six men sitting down talking on a cellphone.           1.0
# 57               ten women paddles a boat down a river.           1.0
# 8921    men playing a round of golf at the golf course.           1.0
# 9445  four men are holding what appears to be a cand...           1.0
# 4798  three women are peering into a cooler of ice c...           1.0
# 846          women are pushing a young girl in a swing.           1.0
# 7994  ten men in blue shorts ride a bike down a street.           1.0
# 9499       some men in a gray shirt next to a white van           1.0
# 7507       ten men in a hat are reaching toward a sign.           1.0
# 8438  two men wearing a leather coat and a white shirt.           1.0
# 6304     five men in green pants walking down the road.           1.0
# 3617  men are resting atop concrete structure in a c...           1.0
# 8024  many men wearing safety goggles are repairing ...           1.0
# 8302               two men looking into a train engine.           1.0
# 6898                 two dogs are running on a pathway.           1.0
# 8876                         men doing a bicycle trick.           1.0
# 8097  four women sitting against a brick wall inside...           1.0
#
#       score_0_exact
# 1982              1
# 1652              1
# 7787              1
# 6500              1
# 57                1
# 8921              1
# 9445              1
# 4798              1
# 846               1
# 7994              1
# 9499              1
# 7507              1
# 8438              1
# 6304              1
# 3617              1
# 8024              1
# 8302              1
# 6898              1
# 8876              1
# 8097              1

# %%
print("Examples of exact matches where is \"to-single\"")
plurals.query('score_0_exact == 1 & subcategory == \'plural|from-single\'').sample(n=20)
# Out:
# Examples of exact matches where is "to-single"
#       Unnamed: 0                                                  a  \
# 9742        9742  Woman in white in foreground and two hundred m...
# 687          687  four men and two women cross the street in fro...
# 1051        1051  five women wearing all white and eating, walk ...
# 1387        1387  five women wearing all white and eating, walk ...
# 2720        2720   women in a green jacket and hood over her hea...
# 5976        5976  twenty two women are walking across the street...
# 9987        9987  twenty women are walking across the street eat...
# 74            74  five women wearing all white and eating, walk ...
# 7576        7576  four women are walking across the street eatin...
# 1768        1768  four women are walking across the street eatin...
# 3048        3048  four men and two women cross the street in fro...
# 4036        4036  four men and some women cross the street in fr...
# 2691        2691  four men and some women cross the street in fr...
# 9779        9779  twenty two women are walking across the street...
# 7018        7018  four women are walking across the street eatin...
# 5180        5180  five men with blond-hair, and a brown shirt dr...
# 5029        5029  Woman in white in foreground and one hundred m...
# 4754        4754  four men and a woman cross the street in front...
# 5204        5204  twenty two women are walking across the street...
# 2014        2014  four men and two women cross the street in fro...
#
#                                                       b  \
# 9742  Woman in white in foreground and a man slightl...
# 687   A man and a woman cross the street in front of...
# 1051  A woman wearing all white and eating, walks ne...
# 1387  A woman wearing all white and eating, walks ne...
# 2720  A woman in a green jacket and hood over her he...
# 5976  A woman is walking across the street eating a ...
# 9987  A woman is walking across the street eating a ...
# 74    A woman wearing all white and eating, walks ne...
# 7576  A woman is walking across the street eating a ...
# 1768  A woman is walking across the street eating a ...
# 3048  A man and a woman cross the street in front of...
# 4036  A man and a woman cross the street in front of...
# 2691  A man and a woman cross the street in front of...
# 9779  A woman is walking across the street eating a ...
# 7018  A woman is walking across the street eating a ...
# 5180  A man with blond-hair, and a brown shirt drink...
# 5029  Woman in white in foreground and a man slightl...
# 4754  A man and a woman cross the street in front of...
# 5204  A woman is walking across the street eating a ...
# 2014  A man and a woman cross the street in front of...
#
#                                                       c  \
# 9742  six men in a green shirt climbs an indoor clim...
# 687      nine men are laying down outside with his dog.
# 1051             four women are rollerblading in public
# 1387   six women dressed in black are playing a violin.
# 2720  three women in a yellow shirt are helping a li...
# 5976            nine women are sitting drinking a drink
# 9987  four men in a red shirt and white shorts are w...
# 74                   five dogs jumps onto the sidewalk.
# 7576      ten men without a shirt working on a rooftop.
# 1768  four women are digging a hole in a garden, usi...
# 3048        some men sing into a microphone on a stage.
# 4036                     five men in a red coat skiing.
# 2691                 six women singing to her children.
# 9779  ten women in a flowered dress are walking down...
# 7018  two men are diving off of a diving board into ...
# 5180  six men wearing blue pants are riding a buckin...
# 5029           two men takes his cat on a walk in town.
# 4754  two men sitting against a building with a woma...
# 5204          three women are taking a picture outside.
# 2014       six women walking down the street in a city.
#
#                                                       d       category  \
# 9742  A man in a green shirt climbs an indoor climbi...     entailment
# 687          A man is laying down outside with his dog.     entailment
# 1051                 A woman is rollerblading in public        neutral
# 1387      A woman dressed in black is playing a violin.        neutral
# 2720  A woman in a yellow shirt is helping a little ...        neutral
# 5976                A woman is sitting drinking a drink        neutral
# 9987  A man in a red shirt and white shorts is walki...  contradiction
# 74                       a dog jumps onto the sidewalk.        neutral
# 7576        A man without a shirt working on a rooftop.  contradiction
# 1768  A woman is digging a hole in a garden, using a...  contradiction
# 3048          A man sings into a microphone on a stage.     entailment
# 4036                        A man in a red coat skiing.  contradiction
# 2691                   a woman singing to her children.  contradiction
# 9779  A woman in a flowered dress is walking down a ...        neutral
# 7018  A man is diving off of a diving board into a p...  contradiction
# 5180  A man wearing blue pants is riding a bucking b...     entailment
# 5029             A man takes his cat on a walk in town.  contradiction
# 4754  A man sitting against a building with a woman ...     entailment
# 5204               A woman is taking a picture outside.        neutral
# 2014         A woman walking down the street in a city.     entailment
#
#              subcategory                                             pred_0  \
# 9742  plural|from-single  a man in a green shirt climbs an indoor climbi...
# 687   plural|from-single         a man is laying down outside with his dog.
# 1051  plural|from-single                 a woman is rollerblading in public
# 1387  plural|from-single      a woman dressed in black is playing a violin.
# 2720  plural|from-single  a woman in a yellow shirt is helping a little ...
# 5976  plural|from-single                a woman is sitting drinking a drink
# 9987  plural|from-single  a man in a red shirt and white shorts is walki...
# 74    plural|from-single                     a dog jumps onto the sidewalk.
# 7576  plural|from-single        a man without a shirt working on a rooftop.
# 1768  plural|from-single  a woman is digging a hole in a garden, using a...
# 3048  plural|from-single          a man sings into a microphone on a stage.
# 4036  plural|from-single                        a man in a red coat skiing.
# 2691  plural|from-single                   a woman singing to her children.
# 9779  plural|from-single  a woman in a flowered dress is walking down a ...
# 7018  plural|from-single  a man is diving off of a diving board into a p...
# 5180  plural|from-single  a man wearing blue pants is riding a bucking b...
# 5029  plural|from-single             a man takes his cat on a walk in town.
# 4754  plural|from-single  a man sitting against a building with a woman ...
# 5204  plural|from-single               a woman is taking a picture outside.
# 2014  plural|from-single         a woman walking down the street in a city.
#
#       score_0_bleu  score_0_exact
# 9742           1.0              1
# 687            1.0              1
# 1051           1.0              1
# 1387           1.0              1
# 2720           1.0              1
# 5976           1.0              1
# 9987           1.0              1
# 74             1.0              1
# 7576           1.0              1
# 1768           1.0              1
# 3048           1.0              1
# 4036           1.0              1
# 2691           1.0              1
# 9779           1.0              1
# 7018           1.0              1
# 5180           1.0              1
# 5029           1.0              1
# 4754           1.0              1
# 5204           1.0              1
# 2014           1.0              1

# %%
print("Examples from top 10% matches where not \"to-single\"")
plurals.query('score_0_exact == 0 & subcategory != \'plural|from-single\'').sort_values(by="score_0_bleu", ascending=False).head(int(len(plurals)*0.10)).sample(n=20)
# Out:
# Examples from top 10% matches where not "to-single"
#       Unnamed: 0                                                  a  \
# 9765        9765  A woman in a blue shirt and green hat looks up...
# 1449        1449  A man carrying a load of fresh direct boxes on...
# 5750        5750  A man on a street in a bright t-shirt holds so...
# 573          573  A woman in a blue shirt and green hat looks up...
# 3690        3690                      A woman is making a clay pot.
# 9314        9314  A woman on the side of a street is making food...
# 5433        5433  A man and two women in black jackets holding u...
# 5280        5280  A woman talks to two other women and a man wit...
# 2339        2339  A man on a street in a bright t-shirt holds so...
# 5724        5724  A man in a red and black jacket, blue shirt, l...
# 837          837  A woman and a girl are playing in a field of l...
# 5551        5551  A man wearing a tan coat signs papers for anot...
# 3937        3937  A man and a woman are holding hands as they wa...
# 9235        9235  A man with wild hair rocks a show playing a gu...
# 586          586  A woman is walking across the street eating a ...
# 3388        3388  A man wearing a striped top and jeans does a s...
# 8113        8113  A man and a woman are standing next to sculptu...
# 7619        7619  A man with blond-hair, and a brown shirt drink...
# 8578        8578  A woman is walking across the street eating a ...
# 6002        6002            A dog jumps to catch a toy in the snow.
#
#                                                       b  \
# 9765  two women in a blue shirt and green hat looks ...
# 1449  nine men carrying a load of fresh direct boxes...
# 5750  ten men on a street in a bright t-shirt holds ...
# 573   three women in a blue shirt and green hat look...
# 3690                 three women are making a clay pot.
# 9314  six women on the side of a street are making f...
# 5433  twenty two men and two women in black jackets ...
# 5280  many women talk to two other women and a man w...
# 2339  five men on a street in a bright t-shirt holds...
# 5724  six men in a red and black jacket, blue shirt,...
# 837   two hundred women and a girl are playing in a ...
# 5551  six men wearing a tan coat signs papers for an...
# 3937  six men and a woman are holding hands as they ...
# 9235  two men with wild hair rocks a show playing a ...
# 586   twenty women are walking across the street eat...
# 3388  some men wearing a striped top and jeans do a ...
# 8113  one hundred men and many women are standing ne...
# 7619  five men with blond-hair, and a brown shirt dr...
# 8578  four women are walking across the street eatin...
# 6002        many dogs jumps to catch a toy in the snow.
#
#                                                       c  \
# 9765  A man in a red shirt plays a red bass while on...
# 1449  A woman looks on as a man with folded arms is ...
# 5750                 A man and women are rock climbing.
# 573          A woman is chasing two sheep with a broom.
# 3690  A woman with a ponytail in a leather jacket is...
# 9314  A man is sitting in a chair with his dog and a...
# 5433    A dog wearing a red harness runs across a field
# 5280       A man wearing goggles is swimming in a pool.
# 2339            A man with a pick axe digging a tunnel.
# 5724        A man in a cherry picker working on a sign.
# 837                A man in a blue t-shirt eats a meal.
# 5551  A man is skating down a rail in front of a gro...
# 3937          A man cleaning an object in the fountain.
# 9235          A man in a red coat is driving a vehicle.
# 586            A dog catches a red Frisbee in the snow.
# 3388  A woman and a man with glasses study an open n...
# 8113     A man wearing sandals walking down the street.
# 7619  A woman in a green shirt is walking down a cro...
# 8578                        A dog running through snow.
# 6002                      A dog is playing with a hose.
#
#                                                       d       category  \
# 9765  two men in a red shirt play a red bass while o...  contradiction
# 1449  nine women looks on as a man with folded arms ...  contradiction
# 5750              some men and women are rock climbing.  contradiction
# 573     three women are chasing two sheep with a broom.     entailment
# 3690  three women with a ponytail in a leather jacke...     entailment
# 9314  six men are sitting in a chair with his dog an...        neutral
# 5433  twenty two dogs wearing a red harness runs acr...  contradiction
# 5280   many men wearing goggles are swimming in a pool.        neutral
# 2339          ten men with a pick axe digging a tunnel.     entailment
# 5724      six men in a cherry picker working on a sign.  contradiction
# 837       two hundred men in a blue t-shirt eat a meal.        neutral
# 5551  six men are skating down a rail in front of a ...     entailment
# 3937        six men cleaning an object in the fountain.  contradiction
# 9235       two men in a red coat are driving a vehicle.  contradiction
# 586      twenty dogs catches a red Frisbee in the snow.  contradiction
# 3388  three women and some men with glasses study an...  contradiction
# 8113  many men wearing sandals walking down the street.     entailment
# 7619  five women in a green shirt are walking down a...     entailment
# 8578                    many dogs running through snow.        neutral
# 6002                 many dogs are playing with a hose.  contradiction
#
#                            subcategory  \
# 9765          plural|to-two|indefinite
# 1449         plural|to-nine|indefinite
# 5750         plural|to-some|indefinite
# 573         plural|to-three|indefinite
# 3690        plural|to-three|indefinite
# 9314          plural|to-six|indefinite
# 5433   plural|to-twenty two|indefinite
# 5280         plural|to-many|indefinite
# 2339          plural|to-ten|indefinite
# 5724          plural|to-six|indefinite
# 837   plural|to-two hundred|indefinite
# 5551          plural|to-six|indefinite
# 3937          plural|to-six|indefinite
# 9235          plural|to-two|indefinite
# 586        plural|to-twenty|indefinite
# 3388         plural|to-some|indefinite
# 8113         plural|to-many|indefinite
# 7619         plural|to-five|indefinite
# 8578         plural|to-many|indefinite
# 6002         plural|to-many|indefinite
#
#                                                  pred_0  score_0_bleu  \
# 9765  two men in a red shirt play on a red stage whi...      0.559368
# 1449  six women are looking on as a man with folded ...      0.549100
# 5750                   men and women are rock climbing.      0.846482
# 573   three women are chasing two rabbits with a broom.      0.596949
# 3690  three women with ponytails in a leather jacket...      0.583404
# 9314  six man is sitting in a chair with his dog and...      0.532801
# 5433  four horse wearing a red harness runs across a...      0.687528
# 5280   some men wearing goggles are swimming in a pool.      0.863340
# 2339         five men with a pick axe digging a tunnel.      0.863340
# 5724      six man in a cherry picker working on a sign.      0.782542
# 837   twenty four toned men in a blue t-shirt eat a ...      0.710299
# 5551  six people are skating down a rail in front of...      0.855526
# 3937            man cleaning an object in the fountain.      0.701397
# 9235         a man in a red coat are driving a vehicle.      0.759836
# 586   three spotted dogs throw a red frisbee in the ...      0.537285
# 3388  two women and a man with glasses study an open...      0.519307
# 8113       ten wearing sandals walking down the street.      0.701397
# 7619  a group of women in a green shirt are walking ...      0.757740
# 8578                    four dogs running through snow.      0.668740
# 6002                 some dogs are playing with a hose.      0.809107
#
#       score_0_exact
# 9765              0
# 1449              0
# 5750              0
# 573               0
# 3690              0
# 9314              0
# 5433              0
# 5280              0
# 2339              0
# 5724              0
# 837               0
# 5551              0
# 3937              0
# 9235              0
# 586               0
# 3388              0
# 8113              0
# 7619              0
# 8578              0
# 6002              0

# %%
print("Examples from top 10% matches where is \"to-single\"")
plurals.query('score_0_exact == 0 & subcategory == \'plural|from-single\'').sort_values(by="score_0_bleu", ascending=False).head(int(len(plurals)*0.10)).sample(n=20)
# Out:
# Examples from top 10% matches where is "to-single"
#       Unnamed: 0                                                  a  \
# 9572        9572  nine women in a green jacket and hood over her...
# 7116        7116  Woman in white in foreground and two hundred m...
# 6843        6843  four men and a woman cross the street in front...
# 2207        2207  Woman in white in foreground and three men sli...
# 2849        2849  A person on three horses jumps over a broken d...
# 6328        6328  twenty women are walking across the street eat...
# 9085        9085  five men with blond-hair, and a brown shirt dr...
# 4240        4240  Woman in white in foreground and three men sli...
# 7988        7988  twenty two men and four women cross the street...
# 18            18  twenty women are walking across the street eat...
# 6743        6743  Woman in white in foreground and many men slig...
# 133          133  one hundred women are walking across the stree...
# 1730        1730  Woman in white in foreground and four men slig...
# 6791        6791  five women wearing all white and eating, walk ...
# 2500        2500  twenty two women are walking across the street...
# 6494        6494  two women wearing all white and eating, walk n...
# 8231        8231  twenty two women in a green jacket and hood ov...
# 3949        3949  twenty women are walking across the street eat...
# 7128        7128  four men and two women cross the street in fro...
# 807          807  two women wearing all white and eating, walk n...
#
#                                                       b  \
# 9572  A woman in a green jacket and hood over her he...
# 7116  Woman in white in foreground and a man slightl...
# 6843  A man and a woman cross the street in front of...
# 2207  Woman in white in foreground and a man slightl...
# 2849  A person on a horse jumps over a broken down a...
# 6328  A woman is walking across the street eating a ...
# 9085  A man with blond-hair, and a brown shirt drink...
# 4240  Woman in white in foreground and a man slightl...
# 7988  A man and a woman cross the street in front of...
# 18    A woman is walking across the street eating a ...
# 6743  Woman in white in foreground and a man slightl...
# 133   A woman is walking across the street eating a ...
# 1730  Woman in white in foreground and a man slightl...
# 6791  A woman wearing all white and eating, walks ne...
# 2500  A woman is walking across the street eating a ...
# 6494  A woman wearing all white and eating, walks ne...
# 8231  A woman in a green jacket and hood over her he...
# 3949  A woman is walking across the street eating a ...
# 7128  A man and a woman cross the street in front of...
# 807   A woman wearing all white and eating, walks ne...
#
#                                                       c  \
# 9572  twenty two men on stilts entertaining a young ...
# 7116  some men are looking up while sitting on the g...
# 6843  nine dogs are running along a beach in front o...
# 2207  four men on a bicycle jumping off a dirt ramp ...
# 2849  Two young boys, one with a tennis ball, play w...
# 6328  twenty men in an orange vest stands on scaffol...
# 9085        some men helping a young child rollerskate.
# 4240  twenty women with reddish hair applies mascara...
# 7988  three men and woman who are trying to sell flo...
# 18    twenty two women in a blue jacket ride a brown...
# 6743      six men drinks orange juice and walk outside.
# 133   nine men wearing a black hat walk along some r...
# 1730  Two men and some women are standing in water w...
# 6791  three men in a green hat are jumping down a sn...
# 2500  twenty dogs are running through a field away f...
# 6494  five men sleeps in front of a painted blue wal...
# 8231  twenty women are rolling her grocery cart acro...
# 3949  twenty dogs rolls on his back in the grass as ...
# 7128  three men are flipping another person while th...
# 807   twenty men are jumping in the air in front of ...
#
#                                                       d       category  \
# 9572         A man on stilts entertaining a young girl.     entailment
# 7116   A man is looking up while sitting on the ground.  contradiction
# 6843  A dog is running along a beach in front of the...     entailment
# 2207  A man on a bicycle jumping off a dirt ramp wit...  contradiction
# 2849  Two young boys, one with a tennis ball, play w...        neutral
# 6328  A man in an orange vest stands on scaffolding ...     entailment
# 9085           A man helping a young child rollerskate.     entailment
# 4240  A woman with reddish hair applies mascara to h...     entailment
# 7988    A man and woman who are trying to sell flowers.        neutral
# 18    A woman in a blue jacket rides a brown pony ne...     entailment
# 6743       A man drinks orange juice and walks outside.     entailment
# 133   A man wearing a black hat walks along a road n...     entailment
# 1730  Two men and a woman are standing in water with...        neutral
# 6791  A man in a green hat is jumping down a snow co...        neutral
# 2500  A dog is running through a field away from a p...        neutral
# 6494  A man sleeps in front of a painted blue wall w...     entailment
# 8231  A woman is rolling her grocery cart across the...  contradiction
# 3949  A dog rolls on his back in the grass as two ot...     entailment
# 7128  A man is flipping another person while the oth...     entailment
# 807   A man is jumping in the air in front of a coas...     entailment
#
#              subcategory                                             pred_0  \
# 9572  plural|from-single       two man on stilts entertaining a young girl.
# 7116  plural|from-single  some men are looking up while sitting on the g...
# 6843  plural|from-single  a lion is running along a beach in front of th...
# 2207  plural|from-single  four men on a bicycle jumping off a dirt ramp ...
# 2849  plural|from-single  two young boys, one with a tennis ball, play i...
# 6328  plural|from-single  a man in an orange vest stands on a scaffold w...
# 9085  plural|from-single           the man helping a young child roll tack.
# 4240  plural|from-single  approximately 80 women with reddish hair appli...
# 7988  plural|from-single  a man and a woman who are trying to sell flowers.
# 18    plural|from-single  a woman in a blue jacket rides a brown horse n...
# 6743  plural|from-single     six man drinks orange juice and walks outside.
# 133   plural|from-single  a man wearing a black hat walks along a road n...
# 1730  plural|from-single  two men and some woman are standing in water w...
# 6791  plural|from-single  a man in a red hat is jumping down a snow cove...
# 2500  plural|from-single  a dog is running through a field from a person...
# 6494  plural|from-single  a man sleeps in front of a painted blue wall w...
# 8231  plural|from-single  a woman is rolling her grocery cart down the s...
# 3949  plural|from-single  a dog rolls on his side in the grass as two ot...
# 7128  plural|from-single  a man is flipping a another person while the o...
# 807   plural|from-single  a tall man is jumping in the air in front of a...
#
#       score_0_bleu  score_0_exact
# 9572      0.840896              0
# 7116      0.638943              0
# 6843      0.826517              0
# 2207      0.556034              0
# 2849      0.667508              0
# 6328      0.670423              0
# 9085      0.516973              0
# 4240      0.570675              0
# 7988      0.701688              0
# 18        0.665205              0
# 6743      0.840896              0
# 133       0.838577              0
# 1730      0.761161              0
# 6791      0.761161              0
# 2500      0.718608              0
# 6494      0.824237              0
# 8231      0.707107              0
# 3949      0.660633              0
# 7128      0.552052              0
# 807       0.546802              0

# %%
print("Examples from bottom 25% matches where not \"to-single\"")
plurals.query('score_0_exact == 0 & subcategory != \'plural|from-single\'').sort_values(by="score_0_bleu", ascending=False).tail(int(len(plurals)*0.10)).sample(n=20)
# Out:
# Examples from bottom 25% matches where not "to-single"
#       Unnamed: 0                                                  a  \
# 3492        3492                            A car sinking in water.
# 751          751                           A man riding a dirt bike
# 2656        2656  A man with a red shirt is watching another man...
# 1286        1286  A man on a street in a bright t-shirt holds so...
# 5409        5409  A child in formal clothing is walking along th...
# 6940        6940  A man and a woman are walking on a street at t...
# 4347        4347  A man with a bright green shirt is talking to ...
# 7569        7569  A woman in a green jacket and hood over her he...
# 877          877  A woman is waiting with children as she is che...
# 5870        5870       An english farmer with a horse pulled wagon.
# 7698        7698                  A man in a blue jacket screaming.
# 2676        2676  Outside by the trees, a woman wearing jeans an...
# 5945        5945  A man holding a green bowling ball stands by t...
# 3270        3270  A woman talks to two other women and a man wit...
# 1444        1444          A man walking along side a clean up crew.
# 1983        1983  A man and a woman are walking on a street at t...
# 2602        2602  A man and a woman are standing next to sculptu...
# 9688        9688                        A dog zips along the beach.
# 3311        3311  Four people are acting behind a woman in a yel...
# 347          347  A woman is walking across the street eating a ...
#
#                                                       b  \
# 3492                  twenty two cars sinking in water.
# 751                   twenty two men riding a dirt bike
# 2656  ten men with a red shirt are watching another ...
# 1286  twenty men on a street in a bright t-shirt hol...
# 5409  three children in formal clothing are walking ...
# 6940  twenty men and six women are walking on a stre...
# 4347  three men with a bright green shirt are talkin...
# 7569  nine women in a green jacket and hood over her...
# 877   two women are waiting with children as she is ...
# 5870   An english farmer with nine horses pulled wagon.
# 7698               four men in a blue jacket screaming.
# 2676  Outside by the trees, two hundred women wearin...
# 5945  nine men holding a green bowling ball stands b...
# 3270  six women talk to two other women and a man wi...
# 1444       some men walking along side a clean up crew.
# 1983  ten men and a woman are walking on a street at...
# 2602  one hundred men and many women are standing ne...
# 9688                     ten dogs zips along the beach.
# 3311  Four people are acting behind ten women in a y...
# 347   many women are walking across the street eatin...
#
#                                                       c  \
# 3492  A woman wearing a black shirt is pointing to g...
# 751   A woman stands next to a child who is riding o...
# 2656  A man partially silhouetted on top of a large ...
# 1286  A horse race with numerous people on the horse...
# 5409  A man in a blue shirt with a yellow bag is alo...
# 6940  A young girl in a yellow shirt is holding a bi...
# 4347  A boy and a man dressed as rodeo clowns standi...
# 7569  A man with a determined look on his face holds...
# 877    A man in a black outfit loading bags of product.
# 5870  A man at a table eating, holding up a lone pot...
# 7698  A man has his shoes shined on the sidewalk on ...
# 2676  A woman sweeps outside of the entrance to a bu...
# 5945  A closeup of a woman walking while wearing a b...
# 3270  The cheerleader in red and white is sitting on...
# 1444  A man with a checked shirt on is carrying a sk...
# 1983  A woman dressed up like Wonder Woman and holdi...
# 2602  A man with an umbrella takes photos during a v...
# 9688  A woman is gazing up at the sky while swinging...
# 3311  A woman in a string bathing suit with a man on...
# 347   A man washing windows is suspended outside a b...
#
#                                                       d       category  \
# 3492  twenty two women wearing a black shirt are poi...        neutral
# 751   three women stands next to twenty two children...        neutral
# 2656  ten men partially silhouetted on top of a larg...     entailment
# 1286  some horses race with numerous people on the h...        neutral
# 5409  three men in a blue shirt with a yellow bag ar...     entailment
# 6940  A young girl in a yellow shirt is holding six ...  contradiction
# 4347  A boy and some men dressed as rodeo clowns sta...  contradiction
# 7569  nine men with a determined look on his face ho...     entailment
# 877   two men in a black outfit loading bags of prod...  contradiction
# 5870  nine men at a table eating, holding up a lone ...  contradiction
# 7698  four men has his shoes shined on the sidewalk ...        neutral
# 2676  two hundred women sweeps outside of the entran...     entailment
# 5945  A closeup of nine women walking while wearing ...  contradiction
# 3270  The cheerleader in red and white is sitting on...  contradiction
# 1444  some men with a checked shirt on are carrying ...        neutral
# 1983  ten women dressed up like Wonder Woman and hol...     entailment
# 2602  many men with an umbrella takes photos during ...     entailment
# 9688  ten women are gazing up at the sky while swing...  contradiction
# 3311  ten women in a string bathing suit with a man ...        neutral
# 347   five men washing windows are suspended outside...     entailment
#
#                            subcategory  \
# 3492   plural|to-twenty two|indefinite
# 751    plural|to-twenty two|indefinite
# 2656          plural|to-ten|indefinite
# 1286         plural|to-some|indefinite
# 5409        plural|to-three|indefinite
# 6940          plural|to-six|indefinite
# 4347         plural|to-some|indefinite
# 7569         plural|to-nine|indefinite
# 877           plural|to-two|indefinite
# 5870         plural|to-nine|indefinite
# 7698         plural|to-four|indefinite
# 2676  plural|to-two hundred|indefinite
# 5945         plural|to-nine|indefinite
# 3270          plural|to-six|indefinite
# 1444         plural|to-some|indefinite
# 1983          plural|to-ten|indefinite
# 2602         plural|to-many|indefinite
# 9688          plural|to-ten|indefinite
# 3311          plural|to-ten|indefinite
# 347          plural|to-five|indefinite
#
#                                                  pred_0  score_0_bleu  \
# 3492  twenty one black men who are holding white let...  8.961672e-08
# 751   ten young women stand next to one another who ...  1.203922e-07
# 2656        five men mostly <unk> onto a rocky surface.  1.446627e-10
# 1286  numerous horse races on the fields with many w...  1.317793e-07
# 5409  a man in a yellow shirt with three brown bags ...  1.429615e-07
# 6940  young yellow present in a microphone is five w...  1.350863e-07
# 4347  three boys and a group of asian men dressed in...  1.257119e-07
# 7569  most had see 8 six youths wearing a large meta...  5.495809e-08
# 877      two man in black suits loading a bag of items.  1.857506e-10
# 5870  a man at four sitting at each table, chewing u...  1.041212e-10
# 7698  four men have their shoes mounted on curb on t...  1.214918e-07
# 2676  several woman passes through the front gate of...  8.562365e-08
# 5945  approximately 15 minutes of smiling as she wal...  1.006264e-07
# 3270  redheaded cheerleaders on the field are dresse...  9.792991e-08
# 1444  there were a few men wearing casual shorts on ...  1.170457e-10
# 1983  very tall woman happily standing all over some...  8.975051e-11
# 2602  despite many years of photos there has a very ...  1.306511e-07
# 9688  twenty women are standing awake on the steps o...  1.246292e-07
# 3311  a woman in a blue sea pattern cap with eleven ...  9.507244e-08
# 347   many people seated on wooden boards sit on a r...  6.384514e-08
#
#       score_0_exact
# 3492              0
# 751               0
# 2656              0
# 1286              0
# 5409              0
# 6940              0
# 4347              0
# 7569              0
# 877               0
# 5870              0
# 7698              0
# 2676              0
# 5945              0
# 3270              0
# 1444              0
# 1983              0
# 2602              0
# 9688              0
# 3311              0
# 347               0

# %%
print("Examples from bottom 25% matches where is \"to-single\"")
plurals.query('score_0_exact == 0 & subcategory == \'plural|from-single\'').sort_values(by="score_0_bleu", ascending=False).tail(int(len(plurals)*0.25)).sample(n=20)
# Out:
# Examples from bottom 25% matches where is "to-single"
#       Unnamed: 0                                                  a  \
# 142          142  A person on ten horses jumps over a broken dow...
# 3630        3630  one hundred women are walking across the stree...
# 1062        1062  three women are walking across the street eati...
# 392          392  A person on three horses jumps over a broken d...
# 8210        8210  four women are walking across the street eatin...
# 7681        7681  four women are walking across the street eatin...
# 9147        9147  A person on  horses jumps over a broken down a...
# 5313        5313  Woman in white in foreground and some men slig...
# 1567        1567  A person on ten horses jumps over a broken dow...
# 2142        2142  Woman in white in foreground and many men slig...
# 6167        6167  Woman in white in foreground and one hundred m...
# 8398        8398  four men and a woman cross the street in front...
# 3987        3987  Woman in white in foreground and ten men sligh...
# 7445        7445  twenty two women are walking across the street...
# 4838        4838  twenty two men and four women cross the street...
# 7249        7249  twenty two women are walking across the street...
# 4114        4114  two women are walking across the street eating...
# 419          419  twenty women are walking across the street eat...
# 9431        9431  four women are walking across the street eatin...
# 6511        6511  Woman in white in foreground and many men slig...
#
#                                                       b  \
# 142   A person on a horse jumps over a broken down a...
# 3630  A woman is walking across the street eating a ...
# 1062  A woman is walking across the street eating a ...
# 392   A person on a horse jumps over a broken down a...
# 8210  A woman is walking across the street eating a ...
# 7681  A woman is walking across the street eating a ...
# 9147  A person on a horse jumps over a broken down a...
# 5313  Woman in white in foreground and a man slightl...
# 1567  A person on a horse jumps over a broken down a...
# 2142  Woman in white in foreground and a man slightl...
# 6167  Woman in white in foreground and a man slightl...
# 8398  A man and a woman cross the street in front of...
# 3987  Woman in white in foreground and a man slightl...
# 7445  A woman is walking across the street eating a ...
# 4838  A man and a woman cross the street in front of...
# 7249  A woman is walking across the street eating a ...
# 4114  A woman is walking across the street eating a ...
# 419   A woman is walking across the street eating a ...
# 9431  A woman is walking across the street eating a ...
# 6511  Woman in white in foreground and a man slightl...
#
#                                                       c  \
# 142   some dogs in the water while three individuals...
# 3630  four men in a striped shirt holds dozens of ba...
# 1062  many men carrying many bags of cans probably g...
# 392   two hundred men biting his nails in a subway w...
# 8210  Woman wearing USA colors, holding a USA Flag, ...
# 7681  ten men wearing a yellow shirt standing in the...
# 9147  four men in a light blue cap are carving an ic...
# 5313   women in a psychic readings shop reads a cust...
# 1567  twenty women sit on a outcropping of rock whil...
# 2142  one hundred men with long hair and wearing a b...
# 6167  five women with the name Steph on her yellow s...
# 8398  Many men in yellow shirts and four women in an...
# 3987  some women are jogging on twenty roads by a sh...
# 7445  A platform floats on a river carrying six men ...
# 4838  A frowning older men leans in the doorway of a...
# 7249  A girl with blue highlights watches some dogs ...
# 4114  nine women brushes her hand against a male at ...
# 419   twenty men wearing a grass skirt, are standing...
# 9431  one hundred women appears to be taking a break...
# 6511   men drags across some branches as a camel are...
#
#                                                       d       category  \
# 142   A dog in the water while three individuals wal...  contradiction
# 3630  A man in a striped shirt holds dozens of ballo...     entailment
# 1062  A man carrying many bags of cans probably goin...        neutral
# 392   A man biting his nails in a subway while using...        neutral
# 8210  Woman wearing USA colors, holding a USA Flag, ...  contradiction
# 7681  a man wearing a yellow shirt standing in the m...  contradiction
# 9147  A man in a light blue cap is carving an ice sc...     entailment
# 5313  A woman in a psychic readings shop reads a cus...     entailment
# 1567  One woman sits on a outcropping of rock while ...  contradiction
# 2142  A man with long hair and wearing a black shirt...     entailment
# 6167  A woman with the name Steph on her yellow shir...  contradiction
# 8398  Many men in yellow shirts and one woman in an ...  contradiction
# 3987  A woman is jogging on a road by a shoreline, h...        neutral
# 7445  A platform floats on a river carrying a man pl...        neutral
# 4838  A frowning older man leans in the doorway of a...        neutral
# 7249  A girl with blue highlights watches a dog leap...        neutral
# 4114  A woman brushes her hand against a male at a c...  contradiction
# 419   A man wearing a grass skirt, is standing in th...  contradiction
# 9431  A woman appears to be taking a break from ridi...        neutral
# 6511  A man drags across some branches as a camel is...        neutral
#
#              subcategory                                             pred_0  \
# 142   plural|from-single  the dogs in a waterway while looking near a ne...
# 3630  plural|from-single  a man in a shirt holds balloons across a crowd...
# 1062  plural|from-single  a man probably carrying lots of cans that are ...
# 392   plural|from-single  tenement stealing a cigarette in his hand whil...
# 8210  plural|from-single  a person wearing a vw flag, holding an america...
# 7681  plural|from-single  a man standing in a mess of all yellow apron a...
# 9147  plural|from-single  three man in a blue mask are a striking stone ...
# 5313  plural|from-single  women in a pharmacy read a patron's brow while...
# 1567  plural|from-single  two women sit on a rock while a picture is tak...
# 2142  plural|from-single  three overweight men with short hair and a shi...
# 6167  plural|from-single  three women with the number 6 on her back are ...
# 8398  plural|from-single  a man in an orange shirt and yellow shorts in ...
# 3987  plural|from-single  several women are walking on a tacky road, whe...
# 7445  plural|from-single  a person rides a platform, singing on a river ...
# 4838  plural|from-single  a businessman leans in the direction of a frow...
# 7249  plural|from-single  a girl with a dog watches moves toward a spott...
# 4114  plural|from-single  a female sweeps her hand at a man upon a rocky...
# 419   plural|from-single  a man wearing a shirt is running on the grass ...
# 9431  plural|from-single  a recently seen woman has stopped riding a bik...
# 6511  plural|from-single  two men crouch on drag drag as another animal ...
#
#       score_0_bleu  score_0_exact
# 142   1.201106e-10              0
# 3630  2.499776e-01              0
# 1062  1.384707e-07              0
# 392   1.201106e-10              0
# 8210  1.202158e-07              0
# 7681  1.479969e-04              0
# 9147  1.801494e-04              0
# 5313  1.392601e-07              0
# 1567  1.196656e-07              0
# 2142  1.033121e-07              0
# 6167  1.030868e-07              0
# 8398  1.653311e-01              0
# 3987  9.629944e-08              0
# 7445  1.121025e-04              0
# 4838  1.634184e-04              0
# 7249  1.777835e-04              0
# 4114  1.251224e-07              0
# 419   1.916453e-01              0
# 9431  1.421167e-10              0
# 6511  1.142337e-04              0

# %% [markdown]
# ## Opposites

# %%
opposite_type_counts = opposites.subcategory.value_counts()
opposite_type_counts
# Out:
# opposite|from-possibly       1778
# opposite|from-decided        1723
# opposite|from-sure           1697
# opposite|from-competitive    1358
# opposite|from-comfortable     551
# opposite|from-known           527
# opposite|from-possible        517
# opposite|from-likely          447
# opposite|from-certain         369
# opposite|from-pleasant        328
# opposite|from-impressive      233
# opposite|from-aware           225
# opposite|from-convenient       65
# opposite|from-responsible      58
# opposite|from-honest           30
# opposite|from-fortunate        23
# opposite|from-reasonable       20
# opposite|from-efficient        14
# opposite|from-productive       14
# opposite|from-informed         13
# opposite|from-informative      10
# Name: subcategory, dtype: int64

# %%
(opposites.groupby(by="subcategory")['score_0_exact'].agg("sum") / opposite_type_counts) * 100
# Out:
# opposite|from-aware          0.444444
# opposite|from-certain        0.000000
# opposite|from-comfortable    1.633394
# opposite|from-competitive    0.000000
# opposite|from-convenient     0.000000
# opposite|from-decided        0.000000
# opposite|from-efficient      0.000000
# opposite|from-fortunate      0.000000
# opposite|from-honest         0.000000
# opposite|from-impressive     0.000000
# opposite|from-informative    0.000000
# opposite|from-informed       0.000000
# opposite|from-known          0.000000
# opposite|from-likely         0.000000
# opposite|from-pleasant       0.000000
# opposite|from-possible       0.000000
# opposite|from-possibly       0.000000
# opposite|from-productive     0.000000
# opposite|from-reasonable     0.000000
# opposite|from-responsible    0.000000
# opposite|from-sure           0.000000
# dtype: float64

# %%
opposites.groupby(by="subcategory")['score_0_bleu'].agg("mean").round(4)
# Out:
# subcategory
# opposite|from-aware          0.1631
# opposite|from-certain        0.2075
# opposite|from-comfortable    0.2125
# opposite|from-competitive    0.2889
# opposite|from-convenient     0.2438
# opposite|from-decided        0.1525
# opposite|from-efficient      0.0000
# opposite|from-fortunate      0.3951
# opposite|from-honest         0.0296
# opposite|from-impressive     0.2227
# opposite|from-informative    0.1903
# opposite|from-informed       0.0004
# opposite|from-known          0.1879
# opposite|from-likely         0.0796
# opposite|from-pleasant       0.3380
# opposite|from-possible       0.1117
# opposite|from-possibly       0.1254
# opposite|from-productive     0.3554
# opposite|from-reasonable     0.3976
# opposite|from-responsible    0.0169
# opposite|from-sure           0.0903
# Name: score_0_bleu, dtype: float64

# %%
opposites.groupby(by="subcategory")['score_0_bleu'].agg("median").round(4)
# Out:
# subcategory
# opposite|from-aware          0.0004
# opposite|from-certain        0.0003
# opposite|from-comfortable    0.0005
# opposite|from-competitive    0.2761
# opposite|from-convenient     0.1769
# opposite|from-decided        0.0002
# opposite|from-efficient      0.0000
# opposite|from-fortunate      0.4301
# opposite|from-honest         0.0000
# opposite|from-impressive     0.0005
# opposite|from-informative    0.0003
# opposite|from-informed       0.0004
# opposite|from-known          0.0003
# opposite|from-likely         0.0001
# opposite|from-pleasant       0.3659
# opposite|from-possible       0.0001
# opposite|from-possibly       0.0002
# opposite|from-productive     0.4567
# opposite|from-reasonable     0.4467
# opposite|from-responsible    0.0001
# opposite|from-sure           0.0001
# Name: score_0_bleu, dtype: float64

# %%
print("Percent of exact values from entire opposite set")
(opposites['score_0_exact'].agg("sum") / len(opposites.index)) * 100
# Out:
# Percent of exact values from entire opposite set
# 0.1

# %%
print("Average bleu score for opposites")
opposites['score_0_bleu'].agg("mean").round(4)
# Out:
# Average bleu score for opposites
# 0.1658

# %%
print("Median bleu score for opposites")
opposites['score_0_bleu'].agg("median").round(6)
# Out:
# Median bleu score for opposites
# 0.000211

# %%
print("Examples of exact matches")
opposites[opposites['score_0_exact'] == 1]
# Out:
# Examples of exact matches
#       Unnamed: 0                                                  a  \
# 210          210  The family is having a pleasant dinner convers...
# 1522        1522                     The woman was very comfortable
# 2406        2406                      It's a pleasant day outdoors.
# 2802        2802               The music at the concert is pleasant
# 2932        2932                    The bicycle seat is comfortable
# 3373        3373                 The bike is comfortable to ride on
# 3633        3633      The man is on a comfortable bed in a mansion.
# 3798        3798  Children are inside wearing comfortable white ...
# 4667        4667  Five men playing a competitive game of basketb...
# 7452        7452                      It's a pleasant day outdoors.
#
#                                                       b  \
# 210   The family is having a unpleasant dinner conve...
# 1522                   The woman was very uncomfortable
# 2406                    It's a unpleasant day outdoors.
# 2802             The music at the concert is unpleasant
# 2932                  The bicycle seat is uncomfortable
# 3373               The bike is uncomfortable to ride on
# 3633    The man is on a uncomfortable bed in a mansion.
# 3798  Children are inside wearing uncomfortable whit...
# 4667  Five men playing a uncompetitive game of baske...
# 7452                    It's a unpleasant day outdoors.
#
#                                                       c  \
# 210                    The man is comfortable sleeping.
# 1522  A person in comfortable clothing moves near th...
# 2406  A person in comfortable clothing moves near th...
# 2802                     The woman was very comfortable
# 2932                          The pants are comfortable
# 3373         Two women are wearing comfortable dresses.
# 3633                    The bicycle seat is comfortable
# 3798               The man is comfortable in the chair.
# 4667                     The man is aware of the pigeon
# 7452         Two women are wearing comfortable dresses.
#
#                                                       d    category  \
# 210                  The man is uncomfortable sleeping.  entailment
# 1522  A person in uncomfortable clothing moves near ...  entailment
# 2406  A person in uncomfortable clothing moves near ...  entailment
# 2802                   The woman was very uncomfortable     neutral
# 2932                        The pants are uncomfortable     neutral
# 3373       Two women are wearing uncomfortable dresses.     neutral
# 3633                  The bicycle seat is uncomfortable     neutral
# 3798             The man is uncomfortable in the chair.     neutral
# 4667                   The man is unaware of the pigeon     neutral
# 7452       Two women are wearing uncomfortable dresses.     neutral
#
#                     subcategory  \
# 210   opposite|from-comfortable
# 1522  opposite|from-comfortable
# 2406  opposite|from-comfortable
# 2802  opposite|from-comfortable
# 2932  opposite|from-comfortable
# 3373  opposite|from-comfortable
# 3633  opposite|from-comfortable
# 3798  opposite|from-comfortable
# 4667        opposite|from-aware
# 7452  opposite|from-comfortable
#
#                                                  pred_0  score_0_bleu  \
# 210                  the man is uncomfortable sleeping.           1.0
# 1522  a person in uncomfortable clothing moves near ...           1.0
# 2406  a person in uncomfortable clothing moves near ...           1.0
# 2802                   the woman was very uncomfortable           1.0
# 2932                        the pants are uncomfortable           1.0
# 3373       two women are wearing uncomfortable dresses.           1.0
# 3633                  the bicycle seat is uncomfortable           1.0
# 3798             the man is uncomfortable in the chair.           1.0
# 4667                   the man is unaware of the pigeon           1.0
# 7452       two women are wearing uncomfortable dresses.           1.0
#
#       score_0_exact
# 210               1
# 1522              1
# 2406              1
# 2802              1
# 2932              1
# 3373              1
# 3633              1
# 3798              1
# 4667              1
# 7452              1

# %%
print("Top 25% of bleu scores in opposites")
opposites[opposites['score_0_exact'] == 0].sort_values(by="score_0_bleu", ascending=False).head(int(len(plurals)*0.10)).sample(n=20)
# Out:
# Top 25% of bleu scores in opposites
#       Unnamed: 0                                                  a  \
# 9739        9739                      It's a pleasant day outdoors.
# 9425        9425  Two male basketball players are playing a comp...
# 7313        7313  A man is doing a skateboarding trick, known as...
# 4323        4323  The old man is sitting alone in the park possi...
# 3063        3063  A popular locally known artist turns the stree...
# 2355        2355  There is one man in the foreground with a hamm...
# 5902        5902  A possible construction worker in an orange ve...
# 4282        4282  The friends have known each other for a long time
# 7231        7231  This is a group of women attending to some bas...
# 1870        1870  A busy plaza with three young women with an um...
# 5448        5448      Many people have photographed a possible UFO.
# 3301        3301  The men were sent by the city to make sure tha...
# 3122        3122  A janitor is cleaning a museum at night in a c...
# 3178        3178  A person in dark outerwear is aware of their s...
# 58            58  A man rides a bicycle on a small bridge over a...
# 1902        1902  The man will likely buy some of the herring pr...
# 9791        9791  An officer makes sure the crowd stays behind t...
# 6635        6635  Six people are outside in the dirt possibly ga...
# 2971        2971  The person looks cautiously into traffic to be...
# 3056        3056                     The team decided to huddle up.
#
#                                                       b  \
# 9739                    It's a unpleasant day outdoors.
# 9425  Two male basketball players are playing a unco...
# 7313  A man is doing a skateboarding trick, unknown ...
# 4323  The old man is sitting alone in the park impos...
# 3063  A popular locally unknown artist turns the str...
# 2355  There is one man in the foreground with a hamm...
# 5902  A impossible construction worker in an orange ...
# 4282  The friends have unknown each other for a long...
# 7231  This is a group of women attending to some bas...
# 1870  A busy plaza with three young women with an um...
# 5448    Many people have photographed a impossible UFO.
# 3301  The men were sent by the city to make unsure t...
# 3122  A janitor is cleaning a museum at night in a u...
# 3178  A person in dark outerwear is unaware of their...
# 58    A man rides a bicycle on a small bridge over a...
# 1902  The man will unlikely buy some of the herring ...
# 9791  An officer makes unsure the crowd stays behind...
# 6635  Six people are outside in the dirt impossibly ...
# 2971  The person looks cautiously into traffic to be...
# 3056                   The team undecided to huddle up.
#
#                                                       c  \
# 9739    The two cyclists have decided to quit the race.
# 9425  A man and a woman are running in a competitive...
# 7313       The man is hoping to reach a certain height.
# 4323   This woman has won a competitive eating contest.
# 3063  A field hockey championship game is decided in...
# 2355     A man is doing an impressive skateboard trick.
# 5902  A man is sitting in a neighborhood known for g...
# 4282   The girl and guy are playing a competitive game.
# 7231  couple in black possibly about to kiss on street.
# 1870  A man is teaching a toddler to be comfortable ...
# 5448         The woman are playing a competitive match.
# 3301  Two men in a fishing boat on a river enjoy a p...
# 3122  A group of Asian protesters stand around a kno...
# 3178  Two Asian men play a competitive game of chess...
# 58            A child having a pleasant time in a swing
# 1902      The women are having a pleasant conversation.
# 9791         The girls are playing a competitive sport.
# 6635  The group of friends have known each other for...
# 2971     A man is doing an impressive skateboard trick.
# 3056   The group of men are playing a competitive game.
#
#                                                       d       category  \
# 9739  The two cyclists have undecided to quit the race.  contradiction
# 9425  A man and a woman are running in a uncompetiti...  contradiction
# 7313     The man is hoping to reach a uncertain height.     entailment
# 4323  This woman has won a uncompetitive eating cont...  contradiction
# 3063  A field hockey championship game is undecided ...        neutral
# 2355   A man is doing an unimpressive skateboard trick.        neutral
# 5902  A man is sitting in a neighborhood unknown for...        neutral
# 4282  The girl and guy are playing a uncompetitive g...        neutral
# 7231  couple in black impossibly about to kiss on st...  contradiction
# 1870  A man is teaching a toddler to be uncomfortabl...        neutral
# 5448       The woman are playing a uncompetitive match.        neutral
# 3301  Two men in a fishing boat on a river enjoy a u...        neutral
# 3122  A group of Asian protesters stand around a unk...        neutral
# 3178  Two Asian men play a uncompetitive game of che...        neutral
# 58          A child having a unpleasant time in a swing  contradiction
# 1902    The women are having a unpleasant conversation.        neutral
# 9791       The girls are playing a uncompetitive sport.        neutral
# 6635  The group of friends have unknown each other f...        neutral
# 2971   A man is doing an unimpressive skateboard trick.        neutral
# 3056  The group of men are playing a uncompetitive g...        neutral
#
#                     subcategory  \
# 9739      opposite|from-decided
# 9425  opposite|from-competitive
# 7313      opposite|from-certain
# 4323  opposite|from-competitive
# 3063      opposite|from-decided
# 2355   opposite|from-impressive
# 5902        opposite|from-known
# 4282  opposite|from-competitive
# 7231     opposite|from-possibly
# 1870  opposite|from-comfortable
# 5448  opposite|from-competitive
# 3301     opposite|from-pleasant
# 3122        opposite|from-known
# 3178  opposite|from-competitive
# 58       opposite|from-pleasant
# 1902     opposite|from-pleasant
# 9791  opposite|from-competitive
# 6635        opposite|from-known
# 2971   opposite|from-impressive
# 3056  opposite|from-competitive
#
#                                                  pred_0  score_0_bleu  \
# 9739    the two cyclists have decided to quit the race.      0.596949
# 9425  a man and a woman are running in a non-profit ...      0.729257
# 7313        the man is hoping to reach a very low goal.      0.638943
# 4323   this woman has won a competitive eating contest.      0.594604
# 3063  a field hockey championship game is delayed in...      0.660633
# 2355     a man is doing an impressive skateboard trick.      0.594604
# 5902  a man is sitting in a neighborhood filled with...      0.570675
# 4282        the girl and guy are playing a random game.      0.750624
# 7231           couple in black about to kiss on street.      0.610195
# 1870  a man is teaching a toddler to interact safely...      0.590047
# 5448         the woman are playing a competitive match.      0.643459
# 3301  two men in a fishing boat on a pleasant river ...      0.688234
# 3122  a group of asian protesters stand around a fak...      0.678650
# 3178  two asian men play a game collage in a park by...      0.587393
# 58            a child having a relaxing time in a swing      0.596949
# 1902      the women are having a pleasant conversation.      0.643459
# 9791         the girls are playing a competitive sport.      0.643459
# 6635  the group of friends have known each other for...      0.734889
# 2971     a man is doing an impressive skateboard trick.      0.594604
# 3056    the group of men are playing an unadorned game.      0.610474
#
#       score_0_exact
# 9739              0
# 9425              0
# 7313              0
# 4323              0
# 3063              0
# 2355              0
# 5902              0
# 4282              0
# 7231              0
# 1870              0
# 5448              0
# 3301              0
# 3122              0
# 3178              0
# 58                0
# 1902              0
# 9791              0
# 6635              0
# 2971              0
# 3056              0

# %%
print("Top 25% of bleu scores in opposites where OPTIMUS didn't generate the value in c")
opposites.query("score_0_exact == 0 & pred_0 != c.str.lower()").sort_values(by="score_0_bleu", ascending=False).head(int(len(plurals)*0.10)).sample(n=20)
# Out:
# Top 25% of bleu scores in opposites where OPTIMUS didn't generate the value in c
#       Unnamed: 0                                                  a  \
# 6610        6610  Two male basketball players are playing a comp...
# 7588        7588  A white man hugging a black man possibly givin...
# 5736        5736  A woman brushes dust and dirt off a possible f...
# 6029        6029  Two women on the street presenting to a crowd,...
# 5262        5262  Lisa gave Bob flowers, but Bob was not certain...
# 4219        4219  An older couple possible in the 70's is in an ...
# 543          543  Two men in a fishing boat on a river enjoy a p...
# 8238        8238  A young girl is fishing with some elderly peop...
# 4091        4091  Asian man standing near street taking picture,...
# 7836        7836          He is running as fast as he possibly can.
# 141          141  The man observes his rice farming, making sure...
# 8789        8789  A man is about to put on an impressive jugglin...
# 1171        1171  An old, possibly homeless man is sitting at a ...
# 1458        1458    The two cyclists have decided to quit the race.
# 2741        2741  Several individuals, some possible Cro-magnons...
# 4168        4168  The catcher decided to let the runner score a ...
# 3498        3498  An officer of the law is making sure no one in...
# 4036        4036               Riding on water is known as sailing.
# 8038        8038     I am really not sure what this group is doing.
# 5088        5088  Two people on a really strange motorcycle in w...
#
#                                                       b  \
# 6610  Two male basketball players are playing a unco...
# 7588  A white man hugging a black man impossibly giv...
# 5736  A woman brushes dust and dirt off a impossible...
# 6029  Two women on the street presenting to a crowd,...
# 5262  Lisa gave Bob flowers, but Bob was not uncerta...
# 4219  An older couple impossible in the 70's is in a...
# 543   Two men in a fishing boat on a river enjoy a u...
# 8238  A young girl is fishing with some elderly peop...
# 4091  Asian man standing near street taking picture,...
# 7836        He is running as fast as he impossibly can.
# 141   The man observes his rice farming, making unsu...
# 8789  A man is about to put on an unimpressive juggl...
# 1171  An old, impossibly homeless man is sitting at ...
# 1458  The two cyclists have undecided to quit the race.
# 2741  Several individuals, some impossible Cro-magno...
# 4168  The catcher undecided to let the runner score ...
# 3498  An officer of the law is making unsure no one ...
# 4036             Riding on water is unknown as sailing.
# 8038   I am really not unsure what this group is doing.
# 5088  Two people on a really strange motorcycle in w...
#
#                                                       c  \
# 6610  A teacher decided to teach the students from h...
# 7588  A competitive jumper is caught by the camera i...
# 5736  A man and a woman are looking at their reflect...
# 6029                 A man looks for a certain address.
# 5262  A man is doing a skateboarding trick, known as...
# 4219             The man is a competitive rock climber.
# 543   The family is having a pleasant dinner convers...
# 8238  There are men watching, to make sure no one fa...
# 4091   The young girl decided not to cook for her meal.
# 7836  Two boys were playing ball, possibly baseball,...
# 141   The old man is sitting alone in the park possi...
# 8789  A woman is running at a competitive race, hold...
# 1171  There is a lady walking with bag possibly groc...
# 1458   The girl and guy are playing a competitive game.
# 2741  3 men and woman waiting outside if a large bui...
# 4168  Man in athletic gear, about to enter a competi...
# 3498  A woman is trying to make sure her two childre...
# 4036  A white man hugging a black man possibly givin...
# 8038  Two monks are walking together possibly contem...
# 5088  Two male basketball players are playing a comp...
#
#                                                       d       category  \
# 6610  A teacher undecided to teach the students from...        neutral
# 7588  A uncompetitive jumper is caught by the camera...     entailment
# 5736  A man and a woman are looking at their reflect...        neutral
# 6029               A man looks for a uncertain address.        neutral
# 5262  A man is doing a skateboarding trick, unknown ...        neutral
# 4219           The man is a uncompetitive rock climber.        neutral
# 543   The family is having a unpleasant dinner conve...        neutral
# 8238  There are men watching, to make unsure no one ...        neutral
# 4091  The young girl undecided not to cook for her m...     entailment
# 7836  Two boys were playing ball, impossibly basebal...        neutral
# 141   The old man is sitting alone in the park impos...  contradiction
# 8789  A woman is running at a uncompetitive race, ho...     entailment
# 1171  There is a lady walking with bag impossibly gr...  contradiction
# 1458  The girl and guy are playing a uncompetitive g...        neutral
# 2741  3 men and woman waiting outside if a large bui...  contradiction
# 4168  Man in athletic gear, about to enter a uncompe...  contradiction
# 3498  A woman is trying to make unsure her two child...        neutral
# 4036  A white man hugging a black man impossibly giv...     entailment
# 8038  Two monks are walking together impossibly cont...     entailment
# 5088  Two male basketball players are playing a unco...     entailment
#
#                     subcategory  \
# 6610      opposite|from-decided
# 7588  opposite|from-competitive
# 5736         opposite|from-sure
# 6029      opposite|from-certain
# 5262        opposite|from-known
# 4219  opposite|from-competitive
# 543      opposite|from-pleasant
# 8238         opposite|from-sure
# 4091      opposite|from-decided
# 7836     opposite|from-possibly
# 141      opposite|from-possibly
# 8789  opposite|from-competitive
# 1171     opposite|from-possibly
# 1458  opposite|from-competitive
# 2741     opposite|from-possibly
# 4168  opposite|from-competitive
# 3498         opposite|from-sure
# 4036     opposite|from-possibly
# 8038     opposite|from-possibly
# 5088  opposite|from-competitive
#
#                                                  pred_0  score_0_bleu  \
# 6610  a teacher decided to teach the students from h...      0.581431
# 7588  a competitive jumper is caught by the camera i...      0.590047
# 5736  a man and a woman are looking at their eyes to...      0.493583
# 6029                a man looks for a specific address.      0.643459
# 5262  a man is doing a skateboarding trick, as a blu...      0.472753
# 4219                  the man is a fierce rock climber.      0.488923
# 543   the family is having a relaxing dinner convers...      0.594604
# 8238  there are men watching, to no one stop the doing.      0.451801
# 4091  the young girl decided not to cook for her din...      0.525382
# 7836  two boys were playing ball, shotting baseball ...      0.475385
# 141   the elderly man is sitting alone in the park h...      0.448150
# 8789  a woman is running at a competing bottled race...      0.583351
# 1171  there is a lady walking with bagpipes impatiently      0.600429
# 1458    the girl and guy are playing competitive <unk>.      0.600429
# 2741  3 men and woman waiting outside of a large bui...      0.460533
# 4168  man in athletic gear, about to deflated into a...      0.537285
# 3498  a woman is trying to make her two children happy.      0.553135
# 4036  a white man hugging a black man refusing to hu...      0.570675
# 8038  two monks are walking together contemplating s...      0.557800
# 5088  two male professional basketball players are p...      0.493558
#
#       score_0_exact
# 6610              0
# 7588              0
# 5736              0
# 6029              0
# 5262              0
# 4219              0
# 543               0
# 8238              0
# 4091              0
# 7836              0
# 141               0
# 8789              0
# 1171              0
# 1458              0
# 2741              0
# 4168              0
# 3498              0
# 4036              0
# 8038              0
# 5088              0

# %%
print("Bottom 25% of bleu scores in opposites")
opposites[opposites['score_0_exact'] == 0].sort_values(by="score_0_bleu", ascending=False).tail(int(len(plurals)*0.25)).sample(n=20)
# Out:
# Bottom 25% of bleu scores in opposites
#       Unnamed: 0                                                  a  \
# 1237        1237  There are men watching, to make sure no one fa...
# 225          225  A young man is participating in a competitive ...
# 9834        9834  A family lost their shoes and decided to climb...
# 554          554                 Two guys decided to go for a swim.
# 1077        1077  A mother is making sure her son doesn't fall o...
# 931          931  A woman is holding a cellphone and possibly wa...
# 6042        6042  A person makes sure that people can see clearl...
# 5973        5973            A competitive skier from very far away.
# 9859        9859  A teacher decided to teach the students from h...
# 7013        7013  The skier is hungover and decided to sleep in ...
# 7946        7946  A man does responsible tree cutting in a safe ...
# 3293        3293  A man chiseling a sculpture, possibly out of s...
# 3273        3273          A man stays comfortable in a sleeping bag
# 8816        8816  Two Asian men play a competitive game of chess...
# 4301        4301  A tour guide in New York is passing by Times S...
# 4653        4653  The men decided it would be a nice day to take...
# 8927        8927  A woman is making sure she is the addressed pe...
# 4067        4067  The cook is looking over the order to make sur...
# 1601        1601  Man in athletic gear, about to enter a competi...
# 4968        4968  Three males are playing a competitive game on ...
#
#                                                       b  \
# 1237  There are men watching, to make unsure no one ...
# 225   A young man is participating in a uncompetitiv...
# 9834  A family lost their shoes and undecided to cli...
# 554                Two guys undecided to go for a swim.
# 1077  A mother is making unsure her son doesn't fall...
# 931   A woman is holding a cellphone and impossibly ...
# 6042  A person makes unsure that people can see clea...
# 5973          A uncompetitive skier from very far away.
# 9859  A teacher undecided to teach the students from...
# 7013  The skier is hungover and undecided to sleep i...
# 7946  A man does irresponsible tree cutting in a saf...
# 3293  A man chiseling a sculpture, impossibly out of...
# 3273        A man stays uncomfortable in a sleeping bag
# 8816  Two Asian men play a uncompetitive game of che...
# 4301  A tour guide in New York is passing by Times S...
# 4653  The men undecided it would be a nice day to ta...
# 8927  A woman is making unsure she is the addressed ...
# 4067  The cook is looking over the order to make uns...
# 1601  Man in athletic gear, about to enter a uncompe...
# 4968  Three males are playing a uncompetitive game o...
#
#                                                       c  \
# 1237  The clean up crew is cleaning up the stairwell...
# 225   ah, this photo is that of a regatta, possibly ...
# 9834  Tests are being done in order to make sure thi...
# 554   A woman who couldn't afford bowling shoes deci...
# 1077  The glass-blower was not happy with her creati...
# 931   A Cirque de Solei performer shows off his impr...
# 6042  There are possibly two or three lights on Wils...
# 5973  Three roller derby girls fought hard to make s...
# 9859  The boy in a red robe was half covered sitting...
# 7013  An older woman possibly yawning while members ...
# 7946      A protest is sure to attract police officers.
# 3293  After an auto accident between the white van a...
# 3273  A young girl holds a younger boy, possibly her...
# 8816  A competitive bicyclist gets money out of an ATM.
# 4301  The three hikers decided to sit under a big oa...
# 4653  A group of kids playing what looks like violin...
# 8927  The person looks cautiously into traffic to be...
# 4067  A tailor uses a long pole to search for a cert...
# 1601  The group of teenagers are playing volleyball ...
# 4968  A child makes sure to stay inside on a cold fa...
#
#                                                       d       category  \
# 1237  The clean up crew is cleaning up the stairwell...     entailment
# 225   ah, this photo is that of a regatta, impossibl...        neutral
# 9834  Tests are being done in order to make unsure t...  contradiction
# 554   A woman who couldn't afford bowling shoes unde...        neutral
# 1077  The glass-blower was not happy with her creati...        neutral
# 931   A Cirque de Solei performer shows off his unim...  contradiction
# 6042  There are impossibly two or three lights on Wi...        neutral
# 5973  Three roller derby girls fought hard to make u...        neutral
# 9859  The boy in a red robe was half covered sitting...     entailment
# 7013  An older woman impossibly yawning while member...  contradiction
# 7946    A protest is unsure to attract police officers.     entailment
# 3293  After an auto accident between the white van a...     entailment
# 3273  A young girl holds a younger boy, impossibly h...     entailment
# 8816  A uncompetitive bicyclist gets money out of an...        neutral
# 4301  The three hikers undecided to sit under a big ...  contradiction
# 4653  A group of kids playing what looks like violin...  contradiction
# 8927  The person looks cautiously into traffic to be...        neutral
# 4067  A tailor uses a long pole to search for a unce...        neutral
# 1601  The group of teenagers are playing volleyball ...  contradiction
# 4968  A child makes unsure to stay inside on a cold ...  contradiction
#
#                     subcategory  \
# 1237         opposite|from-sure
# 225      opposite|from-possibly
# 9834         opposite|from-sure
# 554       opposite|from-decided
# 1077      opposite|from-decided
# 931    opposite|from-impressive
# 6042     opposite|from-possibly
# 5973         opposite|from-sure
# 9859     opposite|from-possibly
# 7013     opposite|from-possibly
# 7946         opposite|from-sure
# 3293         opposite|from-sure
# 3273     opposite|from-possibly
# 8816  opposite|from-competitive
# 4301      opposite|from-decided
# 4653       opposite|from-likely
# 8927         opposite|from-sure
# 4067      opposite|from-certain
# 1601       opposite|from-likely
# 4968         opposite|from-sure
#
#                                                  pred_0  score_0_bleu  \
# 1237  the cleaner's ladder is quickly renovating wha...  7.665461e-11
# 225   finally, there is noone that reads vestrivi's ...  6.654221e-08
# 9834  grades are safe to use in this process because...  9.664110e-11
# 554   a woman without pants intentionally bleachers ...  1.126634e-07
# 1077  the green glass maker was confused and had not...  1.111492e-10
# 931   a judo master troupe snap performs triumphantl...  1.149876e-10
# 6042  there may be two differing wands on a street h...  1.306511e-10
# 5973  three rollerbladers broke down for it all the ...  1.155556e-10
# 9859  a barefooted boy in troubl Robertine wearing a...  1.021064e-07
# 7013  an elderly male who appears to be weeping whil...  9.782376e-11
# 7946    a riot is desperate to show off public protest.  1.907083e-10
# 3293  it was an emergency car crew cleans the multic...  8.062075e-11
# 3273  a young boy becomes a homosexual, surrounded b...  1.291803e-07
# 8816        a freebie attempts to lose excess by <unk>.  1.378434e-10
# 4301  the two hikers ended up sleeping after a small...  7.707532e-08
# 4653  a band of kids wearing only blues all dressed ...  1.305603e-07
# 8927  the pedestrian looks confused and appears to b...  1.167580e-07
# 4067  a skilled archer attempts to attach a long str...  8.097785e-08
# 1601  the teenagers are all camping on a beach to ha...  7.592509e-08
# 4968  a child keeps out so you can get inside a froz...  1.235622e-07
#
#       score_0_exact
# 1237              0
# 225               0
# 9834              0
# 554               0
# 1077              0
# 931               0
# 6042              0
# 5973              0
# 9859              0
# 7013              0
# 7946              0
# 3293              0
# 3273              0
# 8816              0
# 4301              0
# 4653              0
# 8927              0
# 4067              0
# 1601              0
# 4968              0

# %% [markdown]
# ## Comparatives

# %%
comparative_type_counts = comparatives.subcategory.value_counts()
comparative_type_counts
# Out:
# comparative|to-comp      5020
# comparative|from-comp    4980
# Name: subcategory, dtype: int64

# %%
(comparatives.groupby(by="subcategory")['score_0_exact'].agg("sum") / comparative_type_counts) * 100
# Out:
# comparative|from-comp     7.028112
# comparative|to-comp      13.505976
# dtype: float64

# %%
comparatives.groupby(by="subcategory")['score_0_bleu'].agg("mean").round(4)
# Out:
# subcategory
# comparative|from-comp    0.3218
# comparative|to-comp      0.3936
# Name: score_0_bleu, dtype: float64

# %%
comparatives.groupby(by="subcategory")['score_0_bleu'].agg("median").round(4)
# Out:
# subcategory
# comparative|from-comp    0.2690
# comparative|to-comp      0.3508
# Name: score_0_bleu, dtype: float64

# %%
print("Examples of exact matches")
comparatives[comparatives['score_0_exact'] == 1].sample(n=20)
# Out:
# Examples of exact matches
#       Unnamed: 0                                                  a  \
# 4685        4685            The younger people are having a picnic.
# 2770        2770  The large black and white dog likes playing wi...
# 318          318          The dog is pulling a rope from a big dog.
# 8559        8559      An elderly person is helped by a younger man.
# 3565        3565  The black dog runs with a ball with two small ...
# 9171        9171  A young boy and a young girl walking across wa...
# 2864        2864  A woman day dreams about her younger days whil...
# 4319        4319  Large brown cat is jumping over a smaller blac...
# 8005        8005  A small male is walking behind a large male th...
# 237          237  Two tall basketball players are attempting to ...
# 399          399  The man is older than the group of younger people
# 6382        6382  A person is remembering better times when they...
# 3489        3489  A man is watching a younger man shave with an ...
# 2712        2712  A boy rides down the street with a younger boy...
# 2311        2311  Some people wait by a store in the mall while ...
# 7776        7776  The older man and the younger girl is having a...
# 2458        2458  A man and two children, one pointing at the ca...
# 6675        6675  An elderly man watches a younger man grill var...
# 1266        1266          One child is running faster than another.
# 5946        5946                 One wire is larger than the other.
#
#                                                       b  \
# 4685              The young people are having a picnic.
# 2770  The large black and white dog likes playing wi...
# 318        The dog is pulling a rope from a bigger dog.
# 8559        An elderly person is helped by a young man.
# 3565  The black dog runs with a ball with two smalle...
# 9171  A young boy and a younger girl walking across ...
# 2864  A woman day dreams about her young days while ...
# 4319  Large brown cat is jumping over a small black ...
# 8005  A small male is walking behind a larger male t...
# 237   Two tall basketball players are attempting to ...
# 399     The man is older than the group of young people
# 6382  A person is remembering good times when they w...
# 3489  A man is watching a young man shave with an el...
# 2712  A boy rides down the street with a young boy b...
# 2311  Some people wait by a store in the mall while ...
# 7776  The older man and the young girl is having an ...
# 2458  A man and two children, one pointing at the ca...
# 6675  An elderly man watches a young man grill vario...
# 1266                          One child is running fast
# 5946                                  One wire is large
#
#                                                       c  \
# 4685                      a younger woman is on a swing
# 2770                   A guy is helping a younger girl.
# 318               People are moving to a good location.
# 8559                    A dog jumping on a smaller dog.
# 3565             A teenage girl is holding a young boy.
# 9171     A small dog jumps up to play with a large dog.
# 2864  The guy is trying to get a better view to take...
# 4319       The director is trying to get a better shot.
# 8005      There is a child pushing their young sibling.
# 237             A younger woman is currently in motion.
# 399                         a younger man looks nervous
# 6382                              It is colder outside.
# 3489                    a younger man is reading a book
# 2712  A person giving directions to a crowd of young...
# 2311               A man being conned by a smarter man.
# 7776               A younger couple is going for a jog.
# 2458       The marketplace is no long selling products.
# 6675            The older man walks past a younger man.
# 1266             The building is taller than the woman.
# 5946                   a lady talks to younger students
#
#                                                       d       category  \
# 4685                        a young woman is on a swing  contradiction
# 2770                     A guy is helping a young girl.     entailment
# 318             People are moving to a better location.        neutral
# 8559                      A dog jumping on a small dog.     entailment
# 3565           A teenage girl is holding a younger boy.     entailment
# 9171    A small dog jumps up to play with a larger dog.        neutral
# 2864  The guy is trying to get a good view to take a...     entailment
# 4319         The director is trying to get a good shot.     entailment
# 8005    There is a child pushing their younger sibling.     entailment
# 237               A young woman is currently in motion.     entailment
# 399                           a young man looks nervous        neutral
# 6382                                It is cold outside.     entailment
# 3489                      a young man is reading a book        neutral
# 2712  A person giving directions to a crowd of young...     entailment
# 2311                 A man being conned by a smart man.        neutral
# 7776                 A young couple is going for a jog.  contradiction
# 2458     The marketplace is no longer selling products.  contradiction
# 6675              The older man walks past a young man.        neutral
# 1266                               The building is tall     entailment
# 5946                     a lady talks to young students     entailment
#
#                 subcategory  \
# 4685    comparative|to-comp
# 2770    comparative|to-comp
# 318   comparative|from-comp
# 8559    comparative|to-comp
# 3565  comparative|from-comp
# 9171  comparative|from-comp
# 2864    comparative|to-comp
# 4319    comparative|to-comp
# 8005  comparative|from-comp
# 237     comparative|to-comp
# 399     comparative|to-comp
# 6382    comparative|to-comp
# 3489    comparative|to-comp
# 2712    comparative|to-comp
# 2311    comparative|to-comp
# 7776    comparative|to-comp
# 2458  comparative|from-comp
# 6675    comparative|to-comp
# 1266    comparative|to-comp
# 5946    comparative|to-comp
#
#                                                  pred_0  score_0_bleu  \
# 4685                        a young woman is on a swing           1.0
# 2770                     a guy is helping a young girl.           1.0
# 318             people are moving to a better location.           1.0
# 8559                      a dog jumping on a small dog.           1.0
# 3565           a teenage girl is holding a younger boy.           1.0
# 9171    a small dog jumps up to play with a larger dog.           1.0
# 2864  the guy is trying to get a good view to take a...           1.0
# 4319         the director is trying to get a good shot.           1.0
# 8005    there is a child pushing their younger sibling.           1.0
# 237               a young woman is currently in motion.           1.0
# 399                           a young man looks nervous           1.0
# 6382                                it is cold outside.           1.0
# 3489                      a young man is reading a book           1.0
# 2712  a person giving directions to a crowd of young...           1.0
# 2311                 a man being conned by a smart man.           1.0
# 7776                 a young couple is going for a jog.           1.0
# 2458     the marketplace is no longer selling products.           1.0
# 6675              the older man walks past a young man.           1.0
# 1266                               the building is tall           1.0
# 5946                     a lady talks to young students           1.0
#
#       score_0_exact
# 4685              1
# 2770              1
# 318               1
# 8559              1
# 3565              1
# 9171              1
# 2864              1
# 4319              1
# 8005              1
# 237               1
# 399               1
# 6382              1
# 3489              1
# 2712              1
# 2311              1
# 7776              1
# 2458              1
# 6675              1
# 1266              1
# 5946              1

# %%
print("Top 25% of bleu scores in comparative")
comparatives[comparatives['score_0_exact'] == 0].sort_values(by="score_0_bleu", ascending=False).head(int(len(plurals)*0.10)).sample(n=20)
# Out:
# Top 25% of bleu scores in comparative
#       Unnamed: 0                                                  a  \
# 6923        6923  Two women are jogging outdoors, as to lower th...
# 4216        4216  Adult female and younger child, both dressed i...
# 1279        1279  A woman in a skirt and green t-shirt has her a...
# 6350        6350  An older man having his beard shaved by a youn...
# 3416        3416      People are climbing a tree to get a good view
# 6027        6027  There are people climbing a mountain to get a ...
# 3300        3300  Two men walking down the street, the younger h...
# 7721        7721                          A younger man is outside.
# 4637        4637  A mother poses with her son after making an ug...
# 6948        6948  An older man holds a crying toddler next to a ...
# 4293        4293  Two women standing in front of an open door, t...
# 5713        5713           A boy helping a young girl blow bubbles.
# 7608        7608                        a young woman hugging a man
# 9352        9352  People travel on the escalator; some are going...
# 8763        8763  Two men are talking, younger and older, while ...
# 5532        5532         The Cafe Express sign is no longer in use.
# 2038        2038                     A big dog bites a smaller dog.
# 6122        6122  A brown dog with a pink collar with a heart on...
# 7597        7597  A woman day dreams about her young days while ...
# 6595        6595  A young woman wearing a tee-shirt is taking th...
#
#                                                       b  \
# 6923  Two women are jogging outdoors, as to low thei...
# 4216  Adult female and young child, both dressed in ...
# 1279  A woman in a skirt and green t-shirt has her a...
# 6350  An older man having his beard shaved by a youn...
# 3416    People are climbing a tree to get a better view
# 6027  There are people climbing a mountain to get a ...
# 3300  Two men walking down the street, the young hel...
# 7721                            A young man is outside.
# 4637  A mother poses with her son after making an ug...
# 6948  An older man holds a crying toddler next to a ...
# 4293  Two women standing in front of an open door, t...
# 5713         A boy helping a younger girl blow bubbles.
# 7608                      a younger woman hugging a man
# 9352  People travel on the escalator; some are going...
# 8763  Two men are talking, young and older, while th...
# 5532           The Cafe Express sign is no long in use.
# 2038                       A big dog bites a small dog.
# 6122  A brown dog with a pink collar with a heart on...
# 7597  A woman day dreams about her younger days whil...
# 6595  A younger woman wearing a tee-shirt is taking ...
#
#                                                       c  \
# 6923          A man stands next to his younger sisters.
# 4216  An older boy is being kind and helping a young...
# 1279  The young man in the black t-shirt ran in fron...
# 6350                 A young couple is going for a jog.
# 3416  The barefoot man climbs a palm tree for a good...
# 6027  The girl is sitting with the young child on th...
# 3300    There is a child pushing their younger sibling.
# 7721             A crowd is fighting for a better town.
# 4637  The man was given a gift by his younger relative.
# 6948  Man with gray hair telling a story to a group ...
# 4293         The older man is teaching the younger man.
# 5713  The young woman is learning to play a song on ...
# 7608      The game is taking place during a cold month.
# 9352  An older woman is showing a young woman how to...
# 8763  A black and white dog chases a bigger dog acro...
# 5532       The younger people are outside on the grass.
# 2038  The woman stands on the balcony to get a bette...
# 6122        The surfer is swimming out to deeper water.
# 7597            two young men are walking in the street
# 6595      The game is taking place during a cold month.
#
#                                                       d       category  \
# 6923            A man stands next to his young sisters.        neutral
# 4216  An older boy is being kind and helping a young...     entailment
# 1279  The younger man in the black t-shirt ran in fr...  contradiction
# 6350               A younger couple is going for a jog.  contradiction
# 3416  The barefoot man climbs a palm tree for a bett...        neutral
# 6027  The girl is sitting with the younger child on ...  contradiction
# 3300      There is a child pushing their young sibling.     entailment
# 7721               A crowd is fighting for a good town.     entailment
# 4637    The man was given a gift by his young relative.        neutral
# 6948  Man with gray hair telling a story to a group ...  contradiction
# 4293           The older man is teaching the young man.     entailment
# 5713  The younger woman is learning to play a song o...        neutral
# 7608    The game is taking place during a colder month.     entailment
# 9352  An older woman is showing a younger woman how ...  contradiction
# 8763  A black and white dog chases a big dog across ...  contradiction
# 5532         The young people are outside on the grass.     entailment
# 2038  The woman stands on the balcony to get a good ...        neutral
# 6122          The surfer is swimming out to deep water.     entailment
# 7597          two younger men are walking in the street        neutral
# 6595    The game is taking place during a colder month.     entailment
#
#                 subcategory  \
# 6923    comparative|to-comp
# 4216    comparative|to-comp
# 1279  comparative|from-comp
# 6350  comparative|from-comp
# 3416  comparative|from-comp
# 6027  comparative|from-comp
# 3300    comparative|to-comp
# 7721    comparative|to-comp
# 4637    comparative|to-comp
# 6948  comparative|from-comp
# 4293    comparative|to-comp
# 5713  comparative|from-comp
# 7608  comparative|from-comp
# 9352  comparative|from-comp
# 8763    comparative|to-comp
# 5532    comparative|to-comp
# 2038    comparative|to-comp
# 6122    comparative|to-comp
# 7597  comparative|from-comp
# 6595  comparative|from-comp
#
#                                                  pred_0  score_0_bleu  \
# 6923            a man stands next to his older sisters.      0.707107
# 4216  an older boy is being friendly and helping a y...      0.701688
# 1279  the young man in the black t-shirt ran in fron...      0.806501
# 6350                 a young couple is going for a jog.      0.707107
# 3416  the barefoot man climbs a palm tree for a high...      0.807056
# 6027  the girl is sitting with the young child on th...      0.701688
# 3300    there is a child pushing their younger sibling.      0.707107
# 7721                    a crowd is fighting for a fair.      0.701397
# 4637      the man was given a gift by his older friend.      0.759836
# 6948  man with gray hair explaining a story to a gro...      0.815355
# 4293         the older man is teaching the younger man.      0.707107
# 5713  the young woman is learning to play a song on ...      0.826517
# 7608   the game is taking place during a winter season.      0.725980
# 9352  an older woman is showing a young woman how to...      0.761161
# 8763  a black and white dog chases a big white dog a...      0.761161
# 5532       the younger people are outside on the grass.      0.707107
# 2038  the woman stands on the balcony to get a good ...      0.741945
# 6122       the surfer is swimming out to shallow water.      0.707107
# 7597            two young men are walking in the street      0.707107
# 6595    the game is taking place during a winter break.      0.725980
#
#       score_0_exact
# 6923              0
# 4216              0
# 1279              0
# 6350              0
# 3416              0
# 6027              0
# 3300              0
# 7721              0
# 4637              0
# 6948              0
# 4293              0
# 5713              0
# 7608              0
# 9352              0
# 8763              0
# 5532              0
# 2038              0
# 6122              0
# 7597              0
# 6595              0

# %%
print("Bottom 25% of bleu scores in opposites")
comparatives[comparatives['score_0_exact'] == 0].sort_values(by="score_0_bleu", ascending=False).tail(int(len(plurals)*0.25)).sample(n=20)
# Out:
# Bottom 25% of bleu scores in opposites
#       Unnamed: 0                                                  a  \
# 4814        4814  Two soccer players are chasing two balls to se...
# 3879        3879  The older woman is using hand motions while th...
# 2547        2547                                 Two men, one young
# 1360        1360  Two women sit in a tree to get a better view o...
# 2533        2533  a teenager and a young kid are talking at a ga...
# 6766        6766                                   The box is large
# 461          461                          The tennis balls are warm
# 9137        9137  An elderly Amercian woman is fixing a younger ...
# 7528        7528      The quarterback is younger than 99 years old.
# 553          553                                  The baby is small
# 465          465  Two men, one younger and the other older, stat...
# 4417        4417                      The mall is no longer opened.
# 9955        9955  A woman uses a ladder to reach the higher port...
# 1131        1131                            A man for cool weather.
# 1270        1270  Two boys walk out on a military monument over ...
# 4167        4167                            The child is much small
# 9321        9321          The two men are higher than the building.
# 172          172  The men are best friends trying to settle a be...
# 9465        9465  A man, in a plaid shirt, and a younger boy, in...
# 7650        7650  A human with short hair is among a group of yo...
#
#                                                       b  \
# 4814  Two soccer players are chasing two balls to se...
# 3879  The older woman is using hand motions while th...
# 2547  Two men, one younger than the other and wearin...
# 1360  Two women sit in a tree to get a good view of ...
# 2533  a teenager and a younger kid are talking at a ...
# 6766                   The box is larger than her head.
# 461             The tennis balls are warmer than before
# 9137  An elderly Amercian woman is fixing a young gi...
# 7528                           The quarterback is young
# 553               The baby is smaller than the luggage.
# 465   Two men, one young and the other older, statio...
# 4417                        The mall is no long opened.
# 9955  A woman uses a ladder to reach the high portio...
# 1131                          A man for cooler weather.
# 1270  Two boys walk out on a military monument over ...
# 4167          The child is much smaller than the woman.
# 9321                               The two men are high
# 172   The men are best friends trying to settle a be...
# 9465  A man, in a plaid shirt, and a young boy, in a...
# 7650  A human with short hair is among a group of yo...
#
#                                                       c  \
# 4814  A younger man where black clothes is doing a t...
# 3879    The two of them no longer care for one another.
# 2547                                 two young men pray
# 1360  On a grassy lawn, a man (seen only from the fl...
# 2533  Adding aspirin to the water is good for overal...
# 6766  A group of young men standing outside the fron...
# 461                         a young woman hugging a man
# 9137    An mean elderly woman and another younger woman
# 7528  The older woman and younger girl are wrapping ...
# 553   A picture of a live duck on profile with head ...
# 465   The rock formation is several stories taller t...
# 4417  Three children gathered around a rock while on...
# 9955  Two jockeys whip their horses to run faster to...
# 1131  A large woman is advertising for a weight loss...
# 1270  One young looking woman sitting on the opposit...
# 4167           A boy helping a young girl blow bubbles.
# 9321                  The trees are bigger than a foot.
# 172   A young lady is chewing cherries in her nostri...
# 9465                     home based worker works harder
# 7650  A professional roof thatcher thinks about how ...
#
#                                                       d       category  \
# 4814  A young man where black clothes is doing a tri...     entailment
# 3879      The two of them no long care for one another.  contradiction
# 2547                               two younger men pray        neutral
# 1360  On a grassy lawn, a man (seen only from the fl...  contradiction
# 2533  Adding aspirin to the water is better for over...        neutral
# 6766  A group of younger men standing outside the fr...  contradiction
# 461                       a younger woman hugging a man        neutral
# 9137      An mean elderly woman and another young woman        neutral
# 7528  The older woman and young girl are wrapping gi...  contradiction
# 553   A picture of a live duck on profile with head ...        neutral
# 465          The rock formation is several stories tall        neutral
# 4417  Three children gathered around a rock while on...  contradiction
# 9955  Two jockeys whip their horses to run fast towa...        neutral
# 1131  A larger woman is advertising for a weight los...        neutral
# 1270  One younger looking woman sitting on the oppos...  contradiction
# 4167         A boy helping a younger girl blow bubbles.  contradiction
# 9321                                  The trees are big     entailment
# 172   A young lady is chewing cherries in her nostri...  contradiction
# 9465                       home based worker works hard     entailment
# 7650  A professional roof thatcher thinks about how ...        neutral
#
#                 subcategory  \
# 4814    comparative|to-comp
# 3879    comparative|to-comp
# 2547  comparative|from-comp
# 1360    comparative|to-comp
# 2533  comparative|from-comp
# 6766  comparative|from-comp
# 461   comparative|from-comp
# 9137    comparative|to-comp
# 7528    comparative|to-comp
# 553   comparative|from-comp
# 465     comparative|to-comp
# 4417    comparative|to-comp
# 9955    comparative|to-comp
# 1131  comparative|from-comp
# 1270  comparative|from-comp
# 4167  comparative|from-comp
# 9321    comparative|to-comp
# 172   comparative|from-comp
# 9465    comparative|to-comp
# 7650  comparative|from-comp
#
#                                                  pred_0  score_0_bleu  \
# 4814  a young man who is on top of a street doing tr...  1.584450e-04
# 3879                   the two nd have no one to spare.  1.720339e-07
# 2547  two young gay men sit in glasses and pray to w...  8.513012e-11
# 1360  a child wide awake, by the waist of a grassy b...  3.237285e-08
# 2533  adding 1/2 taste to help the water quality is ...  1.306511e-07
# 6766  a young girl standing outside of an older fema...  8.947853e-08
# 461                  a young woman hugging before a man  3.303164e-07
# 9137                       an old and handicapped woman  2.182269e-10
# 7528                            the young girl and wrap  1.919924e-07
# 553   a silhouette image of a male skiier wearing on...  6.871081e-08
# 465   the rock band is many months older than the st...  1.561970e-07
# 4417  three children beat around a large boulder wit...  1.083063e-07
# 9955  two jockeys race to speed their horses away fr...  1.801494e-07
# 1131  a large woman is seeking a rebate for weight o...  1.659039e-07
# 1270  one older female sitting on the left side of a...  1.969222e-04
# 4167  a young woman helping a boy blow bubbles, whil...  1.799653e-07
# 9321                                  the hills are big  5.946036e-07
# 172   a blond lady is chewing her apples in proper j...  1.852797e-04
# 9465                              hard worker work home  4.630777e-10
# 7650  a roof top expert who claims some more work is...  8.513012e-11
#
#       score_0_exact
# 4814              0
# 3879              0
# 2547              0
# 1360              0
# 2533              0
# 6766              0
# 461               0
# 9137              0
# 7528              0
# 553               0
# 465               0
# 4417              0
# 9955              0
# 1131              0
# 1270              0
# 4167              0
# 9321              0
# 172               0
# 9465              0
# 7650              0
